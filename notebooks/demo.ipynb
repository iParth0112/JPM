# %% [markdown]
# # AI Investment Assistant Demo
# This notebook demonstrates fetching data, generating signals, running validation, and backtesting.

# %%
# !pip -q install -r requirements.txt
# !pip -q install -e .

# %%
from ai_investment_assistant import InvestmentAssistant
assistant = InvestmentAssistant()
result = assistant.run("AAPL")
result.signal

# %%
result.validation

# %%
result.backtest
